# %% [markdown]
# <a href="https://colab.research.google.com/github/AlderARS/Projetos-Pyspark/blob/main/Testando_o_Pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Java
# !apt-get update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://cli.github.com/packages stable/main amd64 Packages [344 B]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,520 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
! pip install pyspark

# %%
import os
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()
print(spark.version)
# Out:
# 3.5.1
